# %%
import pandas as pd 
import openpyxl as pxl
import numpy as np 
import statistics as st
from scipy.optimize import minimize, Bounds, LinearConstraint

# %%
df=pd.read_csv("final.csv")
print(df)
final_day=pd.read_csv('finalday.csv')
final_day=final_day[final_day['SERIES']=='EQ']
df=df[df['SERIES']=='EQ']
companies=df['SYMBOL'].unique()
final_day_companies=final_day['SYMBOL'].unique()
print(companies)
len(companies)
print(len(final_day_companies))
companies1=[]
for x in companies:
    for j in final_day_companies:
        if ( x==j):
            companies1.append(x)
            break
print(len(companies1))
companies=companies1
#inal_day_data=final_day.loc(:,['SYMBOL','CLOSE'])
# Out:
#             SYMBOL    CLOSE  TIMESTAMP
# 0        20MICRONS    47.55  04-Jan-10
# 1       3IINFOTECH    88.15  04-Jan-10
# 2          3MINDIA  1850.75  04-Jan-10
# 3       AARTIDRUGS   106.65  04-Jan-10
# 4         AARTIIND    49.75  04-Jan-10
# ...            ...      ...        ...
# 100212  ZODIACLOTH   270.00  01-Jan-16
# 100213       ZUARI   159.50  01-Jan-16
# 100214   ZUARIGLOB   107.50  01-Jan-16
# 100215   ZYDUSWELL   863.35  01-Jan-16
# 100216       ZYLOG     4.45  01-Jan-16
#
# [100217 rows x 3 columns]
# ['20MICRONS' '3IINFOTECH' '3MINDIA' ... 'TTKHLTCARE' 'UMANGDAIRY'
#  'VIKASECO']
# 1474
# 974

# %%
j=1
k=0
ds=[]
for i in companies:
    ds.append(df[df['SYMBOL']==i])
    k+=1
index=0
final_companies=[]
final_prices=[]
for i in ds: 
    if (len(i)==73):
        final_prices.append(i)
        final_companies.append(companies[index])
    index=index+1
len(final_prices)
# Out:
# 391

# %%
##### writing ocmpany wise prices to different sheets in excel ##########
# path='/Users/tejasvichabbra/Desktop/Portfolio_Analysis/out.xlsx'

# excel_book = pxl.load_workbook(path)
    
# for i in range(0,len(ds)):
#     with pd.ExcelWriter(path, engine='openpyxl') as writer: 
#         writer.book = excel_book
#         writer.sheets = {
#             worksheet.title: worksheet
#             for worksheet in excel_book.worksheets
#         }
#         ds[i].to_excel(writer, companies[i], index=False)
#         print(companies[i])
#         writer.save()

# %%
#calculating returns fro each comapny 
returns_list=[]
mean_list=[]
stddev_list=[]
for i in range(0,len(final_companies)): 
    prices=final_prices[i]['CLOSE']
    prices=prices.to_numpy()
    returns=np.zeros(len(prices)-1)
    j=-1
    for h in range((len(prices)-1),0,-1):
        j=j+1
        returns[j]=(prices[h]-prices[h-1])/prices[h-1]
        
    returns_list.append(returns)
    mean_list.append(returns.mean())
    stddev_list.append(returns.std())
len(mean_list)
len(returns_list)
# Out:
# 391

# %%
len(stddev_list)
# Out:
# 391

# %%
correlation=[]
i_index=0
j_index=0
corr_matrix=np.zeros(len(returns_list)**2).reshape(len(returns_list),len(returns_list))
cov_matrix=np.zeros(len(returns_list)**2).reshape(len(returns_list),len(returns_list))

for x in range(0,len(returns_list)):
    i=returns_list[x]
    for y in range(0,len(returns_list)):
        j=returns_list[y]
        corr_temp=np.corrcoef(i, j)
        corr=corr_temp[0][1]
        cov=corr*stddev_list[x]*stddev_list[y]
        corr_matrix[x][y]=corr
        cov_matrix[x][y]=cov

# %%
final_just_prices=[]
for i in final_prices:
    final_just_prices.append(i['CLOSE'])

# %%
##### ALL THE VARIABLES CALCULATED TILL NOW ######

print(len(final_just_prices))# companywise prices arrays 
print(returns_list)# comapnywise returns arrays 
print(mean_list)# company wise mean returns 
print(stddev_list)# companywise stddev of returns
print(corr_matrix)# correlation matrix 
print(cov_matrix)#covariance matrix
# Out:
# 80974, 0.015619231972951484, 0.02362403526030253, 0.0066203947390192875, 0.002991711828110222, 0.031508094461082256, 0.021300536050045685, 0.012491918161734929, -0.003736095510035222, 0.03320213036249928, -0.013824886777019386, 0.024967905322596906, 0.030069123823137298, 0.017227659986333254, 0.008336633650193666, 0.013900756747842635, 0.024784200644547158, 0.018824956867825482, 0.0004430457491170068, -0.009846495803618306, 0.015402850333210446, 0.01474261440189171, -0.0005403804163394729, 0.022160762149090067, 0.006047430558974404, 0.01790882707161451, 0.018981028965682663, 0.021030928399293918, -0.0018683171270279285, 0.003679330310917208, 0.012004771625717529, 0.01964255395352389, 0.00509230411475189, -0.002788652722741132, -0.006270233063691944, -0.0009463415315709753, -0.0009436310667990562, 0.014622248795386344, 0.024665982767356993, 0.014095862761089817, 0.005590605856830289, 0.004288157633758164, 0.005559026993686984, -0.005996630416386372, 0.03373684304333638, 0.0037480517320051415, 0.008782125577188098, 0.005808044432139055, 0.024434633476922603, 0.01951429456092014, 0.004950714079770634, 0.02399264666195554, 0.008226690455438357, -0.02374000757437841, -0.02077508382707151, 0.007430785302295238, -0.0016305278105271288, 0.027160451378181596, -0.03287400698492279, -0.0120682439485265, -0.003330901791102638, 0.00893531768828697, -0.00492186142127119, -0.019238292508292593, -0.0024725258571905795, 0.017240587345697923, 0.002212156654822713, 0.007499121892003933, -0.0005701986314394133, -0.006156282142514726, 0.005999792584604818, 0.023953721740993434, 0.004091210797062161, -0.002407744898017127, 0.01606035604707899, 0.009013902841997665, 0.018689127037885514, -0.006239055380627994, 0.014395683146470082, 0.007490395099740298, 0.024621661666406305, -0.006933443868516492, -0.002907101894096823, -0.005306745619804195, -0.0015509766146042951, 0.027607859948963472, 0.003194697496555613, 0.016845157407501303, -0.006244444036789809, 0.039551733270903146, 0.0008935479139455341, 0.017406346347916105, 0.005689717564639604, 0.004827737186532376, 0.004960917261186068, 0.003306036317959819, 0.014191542843693216, 0.007928796780977954, 0.0312917298470689, 0.015819291546760705, 0.028985625488162272, -0.010538366253289827, 0.008161160867896934, 0.0068805433676786786, 0.012005064058613214, 0.007041111084346961, 0.003320007565949591, -0.004919467321862495, -0.023912001594902303, -0.002007945283621063, 0.005036470386870805, -0.00037261572436381174, 0.00805737012349608, -0.005755653472028154, 0.028687941459317554, 0.019490603880262348, 0.02219796962008358, 0.020469845735047065, -0.006474742192203031, -0.019034020861060715, -0.014387524918412541, -0.01468978547026161, 0.027567203816921293, 0.021361240874243587, 0.03184235581539786, 0.004937285868619283, 0.017837196468087495, 0.01467611797034124, 0.009609798664505639, -0.018420539126242627, 0.008061119098185826, 0.00622077859392853, 0.010534174694070917, 0.01551960183621642, -0.01872438211930881, 0.009453544924348719, 0.04607010559862476, -0.0003616328299666724, 0.019334044529496233, 0.006990833783231878, 0.007433609590605217, 0.006972859614690499, 0.004269353779103666, 0.0026223823395185863, 0.03354708681406225, 0.00492086707528412, 0.02247979115488111, 0.00529126716210263, -0.007117800472766435, 0.01448331305480711, 0.02866904201361101, 0.014424525818074472, 0.022180107350729387, 0.008480729860658722, 0.00670363104069484, 0.05867296853969174, 0.013250254242673391, 0.01145482846990872, -1.3886527754153833e-07, -0.007627750028423928, 0.004818055955618703, 0.0035724380654434595, 0.01790851022499726, 0.006798512327023509, 0.01282578981027955, 0.008703801666400005, -0.0025460575370683464, 0.008200346370749987, -0.006756200700120722, 0.024542084037627632, 0.01784907088749928, 0.02267677138130603, 0.02002872511893868, 0.015776940461634668, -0.0036151911211130044, 0.02026726501633626, -0.0007962886957079619, 0.006143751821740157, 0.003359255442822184, 0.016534195754201023, 0.03810228879102559, -0.022 ...
# [0.1429598677574757, 0.07986228344296073, 0.10869823767271047, 0.16827436016499706, 0.14925018192629644, 0.11559313297960587, 0.17225628996291814, 0.08379382795633147, 0.07773596094028969, 0.1612011412691669, 0.18450721651694904, 0.1387644535736468, 0.2033585022650286, 0.08969708986873527, 0.15939629953327542, 0.1360755079301925, 0.1797398513572379, 0.17137283202735654, 0.20948401684971313, 0.12206869569041187, 0.1358778638283946, 0.09826066213112905, 0.07764361241322469, 0.17858197446539445, 0.16868628876843353, 0.1324784336395981, 0.09303164528047736, 0.13488324442765617, 0.1345265374067338, 0.14602643504220605, 0.08996290024632399, 0.1205683638021522, 0.16864783643355843, 0.1392830158067659, 0.1090104999551095, 0.14115499411473215, 0.13050715794164763, 0.14843945355024524, 0.13653260974490802, 0.1387806191495798, 0.08074754104474063, 0.12835680865466262, 0.17037280307225805, 0.11062559526139734, 0.1601445248666387, 0.22753989306272973, 0.1461450545529456, 0.08977095897579059, 0.13854328501300847, 0.09704426137954725, 0.1540102006964351, 0.06329573758324891, 0.16260057105238843, 0.11336763701194733, 0.09567201490390734, 0.14012449506316704, 0.12752135580129711, 0.14418008865330556, 0.07626059160667259, 0.1389519958331022, 0.1085358814770235, 0.11664232482460038, 0.179749257850624, 0.13450842373818017, 0.10040269896459628, 0.1583776815107339, 0.09408847879572275, 0.08082474613741063, 0.14287058681871662, 0.14906630324260708, 0.07524338787371442, 0.09982705074470644, 0.09857234288923712, 0.10260576595048357, 0.12120938284031921, 0.1693523873686804, 0.07252793252731939, 0.10977417525103284, 0.08716522919827986, 0.1314209256712639, 0.12082158760970221, 0.1269647304822799, 0.06617996323216238, 0.13583731607452693, 0.09833515519774504, 0.18252826553055254, 0.16337202376532814, 0.09531485600448807, 0.13815824330355836, 0.1562347332523478, 0.12505632063122207, 0.11878825074708466, 0.09866870039104515, 0.09182413524224023, 0.12002471313422257, 0.06698678910739093, 0.08204731757211761, 0.08361812875593477, 0.07975330813401346, 0.11279607297719385, 0.13255833208456522, 0.13459718262107961, 0.12083541794181832, 0.12724714239734694, 0.10842067184992021, 0.07332158818287426, 0.09259195328837407, 0.13675863686550102, 0.10809690360349432, 0.08094841339055697, 0.12029905740291594, 0.1406205028899699, 0.07869697540994028, 0.18798704789787188, 0.18704472175567396, 0.1283611889390827, 0.13626317839136085, 0.13657623084216397, 0.17625712989996895, 0.11521856439233227, 0.09086575286180118, 0.13919168707845261, 0.1374833140222503, 0.1922646743557045, 0.13427228628022927, 0.06656371781169007, 0.1170414200420779, 0.09363668358819267, 0.1642725094685927, 0.10385019634130857, 0.11521473197818732, 0.07787673870042734, 0.14603007700665854, 0.1362234466674501, 0.10947153142005145, 0.10750114435514063, 0.1651582756996223, 0.08384369455847163, 0.12201002708279937, 0.1515870007405725, 0.22243699270603673, 0.12188493510018422, 0.08458007135637463, 0.15046179293686418, 0.0944310917440583, 0.08686887472247329, 0.1478111968455572, 0.1475761003504921, 0.1067329460882768, 0.17137210847535708, 0.09935885828180949, 0.1189608661170195, 0.10602845592603928, 0.0990217889747133, 0.1530256682442255, 0.13715419740182022, 0.1365172806037781, 0.06393929455893871, 0.12823852804702324, 0.17389883226393604, 0.07497641037550873, 0.1675627370014243, 0.12897283434565576, 0.07023120071170216, 0.10686949548643276, 0.1093135214210777, 0.07904712127040141, 0.08143974757325459, 0.1657324187947196, 0.06631875300387567, 0.07408736729046238, 0.12947259465951977, 0.09975905414643225, 0.16817682036102907, 0.07907269171411681, 0.09226161460531726, 0.16443263934934882, 0.06695483438205396, 0.09004075782767838, 0.047922848623441636, 0.13573809170621234, 0.04776609252825103, 0.14888557540444902, 0.17668531734728268, 0.0761196664744343, 0.0795937748280072, 0.13411978101400593, 0.07158948850558079, 0.1372351312204681, 0.16334839055426326, 0.0671914601319244, 0.08014593350460036, 0.1705844569241 ...
# [[ 1.00000000e+00  2.91160532e-01  2.58717494e-01 ...  2.09623400e-02
#    1.41648729e-01  5.34044896e-02]
#  [ 2.91160532e-01  1.00000000e+00  3.09967344e-01 ...  5.65098992e-02
#    2.51285182e-01  7.55014713e-02]
#  [ 2.58717494e-01  3.09967344e-01  1.00000000e+00 ...  2.29232901e-01
#    8.78006751e-02  1.30979802e-01]
#  ...
#  [ 2.09623400e-02  5.65098992e-02  2.29232901e-01 ...  1.00000000e+00
#    4.19772629e-04  2.11531776e-01]
#  [ 1.41648729e-01  2.51285182e-01  8.78006751e-02 ...  4.19772629e-04
#    1.00000000e+00 -3.54083261e-02]
#  [ 5.34044896e-02  7.55014713e-02  1.30979802e-01 ...  2.11531776e-01
#   -3.54083261e-02  1.00000000e+00]]
# [[ 2.04375238e-02  3.32420935e-03  4.02033679e-03 ...  3.82687873e-04
#    1.91110196e-03  1.52202296e-03]
#  [ 3.32420935e-03  6.37798432e-03  2.69079225e-03 ...  5.76311197e-04
#    1.89393750e-03  1.20206080e-03]
#  [ 4.02033679e-03  2.69079225e-03  1.18153069e-02 ...  3.18192732e-03
#    9.00694267e-04  2.83828583e-03]
#  ...
#  [ 3.82687873e-04  5.76311197e-04  3.18192732e-03 ...  1.63072828e-02
#    5.05896830e-06  5.38512406e-03]
#  [ 1.91110196e-03  1.89393750e-03  9.00694267e-04 ...  5.05896830e-06
#    8.90664371e-03 -6.66180218e-04]
#  [ 1.52202296e-03  1.20206080e-03  2.83828583e-03 ...  5.38512406e-03
#   -6.66180218e-04  3.97428119e-02]]

# %%
##### forming a list of all the important variables #####
append_list=[]
append_list.append(final_just_prices)
append_list.append(returns_list)
append_list.append(mean_list)
append_list.append(stddev_list)
append_list.append(corr_matrix)
append_list.append(cov_matrix)
append_list.append(weight_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-145-794373432ff5> in <module>
#       7 append_list.append(corr_matrix)
#       8 append_list.append(cov_matrix)
# ----> 9 append_list.append(weight_list)
#
# NameError: name 'weight_list' is not defined

# %%
##### writing all the important variables to different excel sheets of a workbook ###############
name_arrays=['companywise prices arrays','comapnywise returns arrays','company wise mean returns','companywise stddev of returns','correlation matrix','covariance matrix','weighatges']
path='/Users/tejasvichabbra/Desktop/Portfolio_Analysis/to_be_optimised_6yrs.xlsx'
excel_book = pxl.load_workbook(path)
def excel_writer(to_be_written,name):
    with pd.ExcelWriter(path, engine='openpyxl') as writer: 
        writer.book = excel_book
        writer.sheets = {
        worksheet.title: worksheet
        for worksheet in excel_book.worksheets
        }
        pd.DataFrame(to_be_written).to_excel(writer,name, index=False)
        writer.save()

excel_writer(weight_list,'weight_list')#weight 
excel_writer(mean_list,'mean_list')# company wise mean returns 
excel_writer(stddev_list,'stddev_list')# companywise stddev of returns
excel_writer(corr_matrix,'corr_matrix')# correlation matrix 
excel_writer(cov_matrix,'cov_matrix')#covariance matrix

# %%
W = np.ones((len(returns_list),1))*(1.0/len(returns_list))
mean_list=np.array(mean_list)
def optimize(func, W, exp_ret, cov, target_return):
    opt_bounds = Bounds(0, 1)
    opt_constraints = ({'type': 'eq','fun': lambda W: 1.0 - np.sum(W)},{'type': 'eq','fun': lambda W: target_return - W.T@exp_ret})
    optimal_weights = minimize(func, W, 
                               args=(exp_ret, cov),
                               method='SLSQP',
                               bounds=opt_bounds,
                               constraints=opt_constraints)
    return optimal_weights['x']
def ret_risk(W, exp_ret, cov):
    return -((W.T@exp_ret) / (W.T@cov@W)**0.5)
x = optimize(ret_risk,W,mean_list, cov_matrix, 
             target_return=0.1)

# %%
expected_return=mean_list.T@x
expected_risk=(x.T@cov_matrix)@x
print(expected_return)
print(expected_risk)
# Out:
# 0.05867296854369415
# 0.02495532428532326

# %%
tmp=final_day[final_day['SYMBOL']==final_companies[71]]
tmp
# Out:
#         SYMBOL SERIES  OPEN   HIGH   LOW  CLOSE   LAST  PREVCLOSE  TOTTRDQTY  \
# 312  CENTRALBK     EQ  26.2  27.45  26.2   26.8  26.85       26.2   12852669
#
#         TOTTRDVAL    TIMESTAMP  TOTALTRADES          ISIN  Unnamed: 13
# 312  3.439842e+08  07-JUL-2021        17356  INE483A01010          NaN

# %%
ctr=0
indi_final_returns=[]
first_day=pd.read_csv('firstday.csv')
first_day=first_day[first_day['SERIES']=='EQ']
for i in range(0,len(final_companies)):
    tmp=final_day[final_day['SYMBOL']==final_companies[i]]
    end=float(tmp['CLOSE'])
    tmp1=first_day[first_day['SYMBOL']==final_companies[i]]
    start=float(tmp1['CLOSE'])
    ctr+=1
    indi_final_returns.append(end-start)
individual_returns=np.array(indi_final_returns)
individual_returns=individual_returns.reshape(len(indi_final_returns),1)
x=x.reshape(len(x),1)
print(x.shape)
print(individual_returns.shape)
print(sum(x))
print(sum(individual_returns))
final_earnings=x.T@individual_returns
final_earnings
# Out:
# (391, 1)
# (391, 1)
# [1.]
# [409558.09]
# array([[236.40000027]])

# %% [markdown]
# final_companies
